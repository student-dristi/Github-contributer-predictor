# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\Github-Contributer-predictor\src\data\processed\github_contributor_dataset_N3.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of        user.id  n_obs_prs  frac_merged author_association  \
# 0        10137          3     0.333333               NONE
# 1        31669          3     0.666667        CONTRIBUTOR
# 2        58669          3     0.666667        CONTRIBUTOR
# 3        61977          3     1.000000        CONTRIBUTOR
# 4        86842          3     1.000000        CONTRIBUTOR
# ..         ...        ...          ...                ...
# 361  211442274          3     0.333333        CONTRIBUTOR
# 362  215023458          3     1.000000        CONTRIBUTOR
# 363  217855623          3     0.333333        CONTRIBUTOR
# 364  220483717          3     0.000000        CONTRIBUTOR
# 365  228973311          3     0.333333        CONTRIBUTOR
#
#      avg_days_between_prs  days_to_reach_Nth_pr  label
# 0                    44.0                    88      1
# 1                     1.0                     2      1
# 2                     3.0                     7      1
# 3                   180.5                   361      0
# 4                   208.0                   417      0
# ..                    ...                   ...    ...
# 361                   7.5                    15      1
# 362                   8.0                    17      1
# 363                   0.0                     0      1
# 364                   0.0                     0      1
# 365                   3.5                     8      1
#
# [366 rows x 7 columns]>

# %%
df.describe()
# Out:
#             user.id  n_obs_prs  frac_merged  avg_days_between_prs  \
# count  3.660000e+02      366.0   366.000000            366.000000
# mean   6.593742e+07        3.0     0.617486             33.644809
# std    5.625834e+07        0.0     0.367654             70.791587
# min    1.013700e+04        3.0     0.000000              0.000000
# 25%    1.706573e+07        3.0     0.333333              1.000000
# 50%    5.037287e+07        3.0     0.666667              6.000000
# 75%    1.018787e+08        3.0     1.000000             25.750000
# max    2.289733e+08        3.0     1.000000            419.500000
#
#        days_to_reach_Nth_pr       label
# count            366.000000  366.000000
# mean              67.620219    0.636612
# std              141.672652    0.481634
# min                0.000000    0.000000
# 25%                3.000000    0.000000
# 50%               12.000000    1.000000
# 75%               51.500000    1.000000
# max              840.000000    1.000000

# %%
df.label.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %%
df.author_association.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='author_association'>

# %%
df.groupby('author_association')['label'].value_counts().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='author_association,label'>

# %%
plt.hist(df['avg_days_between_prs'], bins=20)
# Out:
# (array([262.,  38.,  14.,   5.,  11.,   6.,   4.,   3.,   2.,   2.,   3.,
#           4.,   4.,   2.,   1.,   1.,   0.,   0.,   2.,   2.]),
#  array([  0.   ,  20.975,  41.95 ,  62.925,  83.9  , 104.875, 125.85 ,
#         146.825, 167.8  , 188.775, 209.75 , 230.725, 251.7  , 272.675,
#         293.65 , 314.625, 335.6  , 356.575, 377.55 , 398.525, 419.5  ]),
#  <BarContainer object of 20 artists>)
